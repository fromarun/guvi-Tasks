# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df=pd.read_csv("/content/college_1.csv")
df1=pd.read_csv("/content/college_2.csv")
d=pd.concat([df,df1])
d.drop_duplicates()
d.head(10)
# Out:
#                    Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0             A.Dharani    82.0   20.0              24500           24500
# 1           V.JEEVITHA     82.0   20.0              21740           21740
# 2           HEMAVATHI.R   100.0  100.0              19680           19680
# 3           Mugunthan S   100.0   47.0              10610           10610
# 4           Sathammai.S   100.0    8.0               8980            8980
# 5          NIVEESHWAR S   100.0    0.0               8200            8200
# 6         KALAIARASAN K    85.0   47.0               7750            7880
# 7  MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 8            J.SUGANTHI    27.0   50.0               5860            5860
# 9          thamizhpaana    29.0    0.0               5500            5500
#
#                                   Department  Rising  python_en  \
# 0           Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
b=d.loc[(d['CodeKata Score']<15000)&(d['CodeKata Score']>10000)]
b.to_csv("Reached_expectations.csv")
b
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3        Mugunthan S   100.0   47.0              10610           10610
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising  python_en  \
# 3           Computer Science and Engineering       0        NaN
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 3                     NaN
# 1                     0.0
# 2                     6.0
# 3                    -1.0

# %%
b1=d.loc[(d["CodeKata Score"]>7000) & (d["CodeKata Score"]<10000)]
b1.to_csv("Needs_Improvement.csv")
b1
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4              Sathammai.S   100.0    8.0               8980            8980
# 5             NIVEESHWAR S   100.0    0.0               8200            8200
# 6            KALAIARASAN K    85.0   47.0               7750            7880
# 7     MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 4                VIINU V P    -1.0   24.0               9150            9150
# 5               Poojitha Y     0.0   35.0               7210            8970
# 6   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 7                Gowtham R    -1.0    4.0               8650            8650
# 8                 shifak N    58.0    0.0               5180            8320
# 9                  Balaji     -1.0   20.0               6170            8160
# 10                Rushitha    -1.0   62.0               7470            8090
# ...

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
b2=d.loc[d["CodeKata Score"]<7000]
b2.to_csv("Unsatisfactory.csv")
b2
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8        J.SUGANTHI    27.0  50.00               5860            5860
# 9      thamizhpaana    29.0   0.00               5500            5500
# 10  Iyappan Samiraj    50.0  24.00               5400            5400
# 11     Ponniyamma.R   100.0  11.25               5380            5380
# 12        SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 30    praveen raj j    24.0   0.00               2380            2380
# 31       AMARNATH D    -1.0  12.00               1890            1890
# 32             bala    32.0   0.00               1720            1720
# 33             XY Z    -1.0  -1.00                  0               0
# 34        Hariharan    -1.0  -1.00                  0               0
#
#                                    Department  Rising  python_en  \
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
a=np.mean(d["Previous Geekions"])
b=np.mean(d["CodeKata Score"])
print(f"average of Previous Geekions: {a}")
print(f"average of CodeKata Score: {b}")
# Out:
# average of Previous Geekions: 3842.3529411764707
# average of CodeKata Score: 4051.764705882353

# %% [markdown]
# ###### No of students participated

# %%
s=d["Name"]
print("No of students participated: 119")
s
# Out:
# No of students participated: 119
# 0         A.Dharani
# 1       V.JEEVITHA
# 2       HEMAVATHI.R
# 3       Mugunthan S
# 4       Sathammai.S
#           ...
# 30    praveen raj j
# 31       AMARNATH D
# 32             bala
# 33             XY Z
# 34        Hariharan
# Name: Name, Length: 119, dtype: object

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
avg_python=np.mean(d["python"])
avg_sql=np.mean(d["mysql"])
avg_pyen=np.mean(d["python_en"])
avg_ct=np.mean(d["computational_thinking"])
print(f"average completion of python course {avg_python}")
print(f"average completion of mysql course {avg_sql}")
print(f"average completion of python_en course {avg_pyen}")
print(f"average completion of computational_thinking course {avg_ct}")
# Out:
# average completion of python course 54.35294117647059
# average completion of mysql course 23.5
# average completion of python_en course 29.65714285714286
# average completion of computational_thinking course 2.2

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
a=d.sort_values(by="Rising",ascending=False)
b=a[0:3]
b
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8            shifak N    58.0    0.0               5180            8320
# 18     Narasimhan Y L    -1.0    0.0               4800            6800
# 2   Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                                 Department  Rising  python_en  \
# 8   Electronics and Electrical Engineering    3140        0.0
# 18        Computer Science and Engineering    2000       -1.0
# 2         Computer Science and Engineering    2000       55.0
#
#     computational_thinking
# 8                      0.0
# 18                     0.0
# 2                      6.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
a=d.sort_values(by="CodeKata Score",ascending=False)
a[0:3]
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
a=d["Department"].unique()
cse=d.loc[d["Department"]=='Computer Science and Engineering']
ece=d.loc[d["Department"]=='Electronics and Communication Engineering']
eee=d.loc[d["Department"]=='Electronics and Electrical Engineering']

# %%
print(cse.shape)
print(ece.shape)
print(eee.shape)
print(d.shape)
# Out:
# (63, 9)
# (39, 9)
# (17, 9)
# (119, 9)

# %%
cse_per=(63/119)*100
ece_per=(39/119)*100
eee_per=(17/119)*100
print(cse_per,ece_per,eee_per)
# Out:
# 52.94117647058824 32.773109243697476 14.285714285714285

# %%
y=np.array([52.94,32.77,14.3])
explode=(0.3,0,0)
my=['Computer Science and Engineering','Electronics and Communication Engineering','Electronics and Electrical Engineering']
plt.pie(y,labels=my,explode=explode,shadow=True,autopct='%1.1f%%',startangle=90)
plt.legend(title="Department wise codekata performence")
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
cse=d.loc[d["Department"]=="Computer Science and Engineering"].sort_values(by="CodeKata Score",ascending=False)
cse1=cse.iloc[0]
cse1
# Out:
# Name                                             A.Dharani
# python                                                82.0
# mysql                                                 20.0
# Previous Geekions                                    24500
# CodeKata Score                                       24500
# Department                Computer Science and Engineering
# Rising                                                   0
# python_en                                              NaN
# computational_thinking                                 NaN
# Name: 0, dtype: object

# %%
ece=d.loc[d["Department"]=="Electronics and Communication Engineering"].sort_values(by="CodeKata Score",ascending=False)
ece1=ece.iloc[0]
ece1
# Out:
# Name                                                Bodipudi Harini
# python                                                         -1.0
# mysql                                                          35.0
# Previous Geekions                                             10040
# CodeKata Score                                                10040
# Department                Electronics and Communication Engineering
# Rising                                                            0
# python_en                                                       0.0
# computational_thinking                                         -1.0
# Name: 3, dtype: object

# %%
eee=d.loc[d["Department"]=="Electronics and Electrical Engineering"].sort_values(by="CodeKata Score",ascending=False)
eee1=eee.iloc[0]
eee1
# Out:
# Name                                               ASHOK KUMAR K
# python                                                     100.0
# mysql                                                       31.0
# Previous Geekions                                          19400
# CodeKata Score                                             19400
# Department                Electronics and Electrical Engineering
# Rising                                                         0
# python_en                                                    0.0
# computational_thinking                                       9.0
# Name: 0, dtype: object

# %%
df=pd.DataFrame(np.array([24500,10040,19400]),index=['Computer Science and Engineering','Electronics and Communication Engineering','Electronics and Electrical Engineering'])
df.plot.barh(title="Department wise toppers",color="red")
